# %%
from main import people_merged
import numpy as np

# %%
df = people_merged()
# Out:
# ====== Running pipeline PeopleMerged =====
# Found item filename str
# Found item people_krs PeopleKRSMerged
# Initializing people_krs PeopleKRSMerged
#   ====== Running pipeline PeopleKRSMerged =====
# Found item filename str
# Found item people_krs PeopleKRS
# Initializing people_krs PeopleKRS
#     ====== Running pipeline PeopleKRS =====
# Found item filename str
# Finished initialization
# Reading LocalFile(filename='person_krs.jsonl', folder='versioned')
# File doesn't exist, continuing:  [Errno 2] No such file or directory: 'versioned/person_krs.jsonl'
# No df file, processing
# Reading CloudStorage(hostname='rejestr.io')
# 6109it [00:06, 1014.76it/s]
# Processing done
# Reading LocalFile(filename='person_krs.jsonl', folder='versioned')
# File doesn't exist, continuing:  [Errno 2] No such file or directory: 'versioned/person_krs.jsonl'
# Dumping...
# Writing person_krs...
# Done
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = people_merged()
#
# File ~/Programming/koryta/data/scrapers/src/main.py:173, in people_merged()
#     172 def people_merged():
# --> 173     run_pipeline(PeopleMerged)
#
# File ~/Programming/koryta/data/scrapers/src/main.py:118, in run_pipeline(pipeline_type, ctx, nested)
#     116     if issubclass(pipeline_type, PipelineModel):
#     117         print("Initializing", annotation, pipeline_type.__name__)
# --> 118         pipeline_model.__dict__[annotation] = run_pipeline(
#     119             pipeline_type, ctx, nested + 1
#     120         )
#     121 print("Finished initialization")
#     123 pipeline = Pipeline(pipeline_model.process, pipeline_model.filename)
#
# File ~/Programming/koryta/data/scrapers/src/main.py:118, in run_pipeline(pipeline_type, ctx, nested)
#     116     if issubclass(pipeline_type, PipelineModel):
#     117         print("Initializing", annotation, pipeline_type.__name__)
# --> 118         pipeline_model.__dict__[annotation] = run_pipeline(
#     119             pipeline_type, ctx, nested + 1
#     120         )
#     121 print("Finished initialization")
#     123 pipeline = Pipeline(pipeline_model.process, pipeline_model.filename)
#
# File ~/Programming/koryta/data/scrapers/src/main.py:125, in run_pipeline(pipeline_type, ctx, nested)
#     123 pipeline = Pipeline(pipeline_model.process, pipeline_model.filename)
#     124 f = setup_pipeline(pipeline, ctx)
# --> 125 f()
#     126 print(f"{'  ' * nested}====== Finished pipeline {pipeline_name} =====\n\n")
#     127 return pipeline
#
# File ~/Programming/koryta/data/scrapers/src/main.py:140, in setup_pipeline.<locals>.func()
#     136     dumper = (  # TODO fix it
#     137         ctx_var.io.dumper  # pyright: ignore[reportAttributeAccessIssue]
#     138     )
#     139 try:
# --> 140     pipeline_object.process(ctx_var)
#     141     print("Finished processing")
#     142 finally:
#
# File ~/Programming/koryta/data/scrapers/src/scrapers/stores.py:262, in Pipeline.process(self, ctx)
#     261 def process(self, ctx: Context):
# --> 262     return Pipeline.read_or_process(ctx, self.filename, self._process)
#
# File ~/Programming/koryta/data/scrapers/src/scrapers/stores.py:317, in Pipeline.read_or_process(ctx, filename, process)
#     314     assert filename is not None
#     315     df, _ = Pipeline.read(ctx, filename)
# --> 317 assert df is not None
#     318 return df
#
# AssertionError:

# %%
filtered = df[df["krs_name"] == "Krzysztof Kazimierz Czeszejko-Sochacki"]
display(filtered)

def is_unique(s):
    a = s.to_numpy()
    return (a[0] == a).all()

non_unique_cols = []
for col in filtered.columns:
    if col.startswith("metaphone") or col.startswith("elections") or col.startswith("teryt"):
        continue
    if not is_unique(filtered[col]):
        non_unique_cols.append(col)
        
display(filtered[non_unique_cols])
