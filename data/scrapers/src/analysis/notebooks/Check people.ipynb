# %%
from main import people_merged
import numpy as np

# %%
df = people_merged()
# Out:
# ====== Running pipeline PeopleMerged =====
# Initializing people_krs PeopleKRSMerged
#   ====== Running pipeline PeopleKRSMerged =====
# Initializing people_krs PeopleKRS
#     ====== Running pipeline PeopleKRS =====
# Finished initialization
# Reading LocalFile(filename='person_krs.jsonl', folder='versioned')
# Writing to versioned/person_krs.jsonl
# Dumping...
# Done
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = people_merged()
#
# File ~/Programming/koryta/data/scrapers/src/main.py:174, in people_merged()
#     173 def people_merged():
# --> 174     run_pipeline(PeopleMerged)
#
# File ~/Programming/koryta/data/scrapers/src/main.py:119, in run_pipeline(pipeline_type, ctx, nested)
#     117     if isinstance(pipeline_type, type) and issubclass(pipeline_type, PipelineModel):
#     118         print("Initializing", annotation, pipeline_type.__name__)
# --> 119         pipeline_model.__dict__[annotation] = run_pipeline(
#     120             pipeline_type, ctx, nested + 1
#     121         )
#     122 print("Finished initialization")
#     124 pipeline = Pipeline(pipeline_model.process, pipeline_model.filename)
#
# File ~/Programming/koryta/data/scrapers/src/main.py:119, in run_pipeline(pipeline_type, ctx, nested)
#     117     if isinstance(pipeline_type, type) and issubclass(pipeline_type, PipelineModel):
#     118         print("Initializing", annotation, pipeline_type.__name__)
# --> 119         pipeline_model.__dict__[annotation] = run_pipeline(
#     120             pipeline_type, ctx, nested + 1
#     121         )
#     122 print("Finished initialization")
#     124 pipeline = Pipeline(pipeline_model.process, pipeline_model.filename)
#
# File ~/Programming/koryta/data/scrapers/src/main.py:126, in run_pipeline(pipeline_type, ctx, nested)
#     124 pipeline = Pipeline(pipeline_model.process, pipeline_model.filename)
#     125 f = setup_pipeline(pipeline, ctx)
# --> 126 f()
#     127 print(f"{'  ' * nested}====== Finished pipeline {pipeline_name} =====\n\n")
#     128 return pipeline
#
# File ~/Programming/koryta/data/scrapers/src/main.py:141, in setup_pipeline.<locals>.func()
#     137     dumper = (  # TODO fix it
#     138         ctx_var.io.dumper  # pyright: ignore[reportAttributeAccessIssue]
#     139     )
#     140 try:
# --> 141     pipeline_object.process(ctx_var)
#     142     print("Finished processing")
#     143 finally:
#
# File ~/Programming/koryta/data/scrapers/src/scrapers/stores.py:262, in Pipeline.process(self, ctx)
#     261 def process(self, ctx: Context):
# --> 262     return Pipeline.read_or_process(ctx, self.filename, self._process)
#
# File ~/Programming/koryta/data/scrapers/src/scrapers/stores.py:330, in Pipeline.read_or_process(ctx, filename, process)
#     328     json_path = "versioned/" + json_path
#     329     print(f"Writing to {json_path}")
# --> 330     df.to_json(json_path, orient="records", lines=True)
#     332 if df is None:
#     333     assert filename is not None
#
# File ~/Programming/koryta/data/scrapers/.venv/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Programming/koryta/data/scrapers/.venv/lib/python3.13/site-packages/pandas/core/generic.py:2721, in NDFrame.to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options, mode)
#    2718 config.is_nonnegative_int(indent)
#    2719 indent = indent or 0
# -> 2721 return json.to_json(
#    2722     path_or_buf=path_or_buf,
#    2723     obj=self,
#    2724     orient=orient,
#    2725     date_format=date_format,
#    2726     double_precision=double_precision,
#    2727     force_ascii=force_ascii,
#    2728     date_unit=date_unit,
#    2729     default_handler=default_handler,
#    2730     lines=lines,
#    2731     compression=compression,
#    2732     index=index,
#    2733     indent=indent,
#    2734     storage_options=storage_options,
#    2735     mode=mode,
#    2736 )
#
# File ~/Programming/koryta/data/scrapers/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:217, in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options, mode)
#     213     s = convert_to_line_delimits(s)
#     215 if path_or_buf is not None:
#     216     # apply compression and byte/text conversion
# --> 217     with get_handle(
#     218         path_or_buf, mode, compression=compression, storage_options=storage_options
#     219     ) as handles:
#     220         handles.handle.write(s)
#     221 else:
#
# File ~/Programming/koryta/data/scrapers/.venv/lib/python3.13/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/Programming/koryta/data/scrapers/.venv/lib/python3.13/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'versioned'

# %%
filtered = df[df["krs_name"] == "Krzysztof Kazimierz Czeszejko-Sochacki"]
display(filtered)

def is_unique(s):
    a = s.to_numpy()
    return (a[0] == a).all()

non_unique_cols = []
for col in filtered.columns:
    if col.startswith("metaphone") or col.startswith("elections") or col.startswith("teryt"):
        continue
    if not is_unique(filtered[col]):
        non_unique_cols.append(col)
        
display(filtered[non_unique_cols])
