# %%
from main import people_merged
import numpy as np

# %%
df = people_merged()
# Out:
# ====== Running pipeline PeopleMerged =====
# Found item filename str
# Found item people_krs PeopleKRSMerged
# Initializing people_krs PeopleKRSMerged
#   ====== Running pipeline PeopleKRSMerged =====
# Found item filename str
# Found item people_krs PeopleKRS
# Initializing people_krs PeopleKRS
#     ====== Running pipeline PeopleKRS =====
# Found item filename str
# Finished initialization
# Reading LocalFile(filename='person_krs.jsonl', folder='versioned')
# File doesn't exist, continuing:  [Errno 2] No such file or directory: 'versioned/person_krs.jsonl'
# No df file, processing
# Reading CloudStorage(hostname='rejestr.io')
# 648it [00:01, 837.52it/s]
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000002251', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000002251', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa5d00>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000002251/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000002251.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6de0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000002251/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000002251.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6ca0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000002710', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000002710', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6c00>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000002710/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000002710.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6d40>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000002710/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000002710.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6fc0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000004324', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000004324', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6ca0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000004324/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000004324.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6e80>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000004324/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000004324.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7060>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000006791', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000006791', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6fc0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000006791/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000006791.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7060>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000006791/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000006791.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6e80>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000007411', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000007411', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa5d00>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000007411/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000007411.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6e80>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000007411/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000007411.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7100>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000008042', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000008042', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7240>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000008042/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000008042.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7100>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000008042/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000008042.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa5d00>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000009831', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000009831', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6de0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000009831/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000009831.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7240>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000009831/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000009831.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7560>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000010660', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000010660', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6ca0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000010660/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000010660.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7560>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000010660/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000010660.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa72e0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000010696', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000010696', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6ca0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000010696/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000010696.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7420>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000010696/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000010696.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7380>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000011737', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000011737', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6ca0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000011737/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000011737.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7380>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000011737/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000011737.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6de0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000011871', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000011871', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6fc0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000011871/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000011871.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7240>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000011871/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000011871.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa74c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000012483', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000012483', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa72e0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000012483/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000012483.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa74c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000012483/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000012483.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7240>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000014128', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000014128', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa77e0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000014128/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000014128.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7880>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000014128/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000014128.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6de0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000015501', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000015501', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7920>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000015501/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000015501.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6de0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000015501/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000015501.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa76a0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000015552', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000015552', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa79c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000015552/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000015552.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7420>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000015552/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000015552.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7740>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000016065', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000016065', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa79c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000016065/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000016065.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7740>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000016065/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000016065.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7560>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000016274', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000016274', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa79c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000016274/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000016274.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7560>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000016274/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000016274.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa79c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000016853', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000016853', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7060>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000016853/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000016853.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa79c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000016853/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000016853.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7740>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000019193', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000019193', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa76a0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000019193/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000019193.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7420>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000019193/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000019193.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7c40>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000019230', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000019230', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7740>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000019230/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000019230.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7c40>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000019230/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000019230.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6fc0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000019880', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000019880', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7ce0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000019880/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000019880.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa6fc0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000019880/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000019880.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa72e0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000020227', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000020227', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12c7a6020>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000020227/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000020227.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa72e0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000020227/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000020227.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7ce0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000022693', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000022693', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12c7a6020>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000022693/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000022693.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7ce0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000022693/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000022693.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7ba0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000023302', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000023302', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7d80>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000023302/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000023302.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7560>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000023302/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000023302.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa74c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000024354', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000024354', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7ba0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000024354/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000024354.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa74c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000024354/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000024354.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7240>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000025769', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000025769', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa79c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000025769/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000025769.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7240>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000025769/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000025769.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa79c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000026438', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000026438', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7ce0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000026438/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000026438.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa79c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000026438/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000026438.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7a60>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000027151', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000027151', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7740>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000027151/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000027151.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa74c0>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000027151/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000027151.krs-powiazania.aktualnosc_historyczne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7240>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000027471', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000027471', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7a60>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000027471/krs-powiazania/aktualnosc_aktualne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000027471.krs-powiazania.aktualnosc_aktualne', complex_download=None, download_lambda=<function Client.cached_storage.<locals>.<lambda> at 0x12ffa7240>)
# Reading DownloadableFile(url='gs://koryta-pl-crawled/hostname=rejestr.io/date=2025-09-28/api/v2/org/0000027471/krs-powiazania/aktualnosc_historyczne', filename_fallback='hostname=rejestr.io.date=2025-09-28.api.v2.org.0000
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = people_merged()
#
# File ~/Programming/koryta/data/scrapers/src/main.py:166, in people_merged()
#     165 def people_merged():
# --> 166     run_pipeline(PeopleMerged)
#
# File ~/Programming/koryta/data/scrapers/src/main.py:111, in run_pipeline(pipeline_type, ctx, nested)
#     109     if issubclass(pipeline_type, PipelineModel):
#     110         print("Initializing", annotation, pipeline_type.__name__)
# --> 111         pipeline_model.__dict__[annotation] = run_pipeline(
#     112             pipeline_type, ctx, nested + 1
#     113         )
#     114 print("Finished initialization")
#     116 pipeline = Pipeline(pipeline_model.process, pipeline_model.filename)
#
# File ~/Programming/koryta/data/scrapers/src/main.py:111, in run_pipeline(pipeline_type, ctx, nested)
#     109     if issubclass(pipeline_type, PipelineModel):
#     110         print("Initializing", annotation, pipeline_type.__name__)
# --> 111         pipeline_model.__dict__[annotation] = run_pipeline(
#     112             pipeline_type, ctx, nested + 1
#     113         )
#     114 print("Finished initialization")
#     116 pipeline = Pipeline(pipeline_model.process, pipeline_model.filename)
#
# File ~/Programming/koryta/data/scrapers/src/main.py:118, in run_pipeline(pipeline_type, ctx, nested)
#     116 pipeline = Pipeline(pipeline_model.process, pipeline_model.filename)
#     117 f = setup_pipeline(pipeline, ctx)
# --> 118 f()
#     119 print(f"{'  ' * nested}====== Finished pipeline {pipeline_name} =====\n\n")
#     120 return pipeline
#
# File ~/Programming/koryta/data/scrapers/src/main.py:133, in setup_pipeline.<locals>.func()
#     129     dumper = (  # TODO fix it
#     130         ctx_var.io.dumper  # pyright: ignore[reportAttributeAccessIssue]
#     131     )
#     132 try:
# --> 133     pipeline_object.process(ctx_var)
#     134     print("Finished processing")
#     135 finally:
#
# File ~/Programming/koryta/data/scrapers/src/scrapers/stores.py:264, in Pipeline.process(self, ctx)
#     263 def process(self, ctx: Context):
# --> 264     return Pipeline.read_or_process(ctx, self.filename, self._process)
#
# File ~/Programming/koryta/data/scrapers/src/scrapers/stores.py:319, in Pipeline.read_or_process(ctx, filename, process)
#     316     assert filename is not None
#     317     df, _ = Pipeline.read(ctx, filename)
# --> 319 assert df is not None
#     320 return df
#
# AssertionError:

# %%
filtered = df[df["krs_name"] == "Krzysztof Kazimierz Czeszejko-Sochacki"]
display(filtered)

def is_unique(s):
    a = s.to_numpy()
    return (a[0] == a).all()

non_unique_cols = []
for col in filtered.columns:
    if col.startswith("metaphone") or col.startswith("elections") or col.startswith("teryt"):
        continue
    if not is_unique(filtered[col]):
        non_unique_cols.append(col)
        
display(filtered[non_unique_cols])
