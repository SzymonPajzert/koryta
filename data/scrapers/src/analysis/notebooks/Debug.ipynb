# %%
import pandas as pd
import numpy as np
from util.config import versioned
from datetime import datetime, timedelta, date
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from IPython.display import display
from collections import Counter

# %%
people_pkw = pd.DataFrame(versioned.read_jsonl("people_pkw.jsonl"))
people_pkw

# %%
last_name = "Kuśmierski"
first_name = "Krystian"
people_pkw[people_pkw["pkw_name"].str.match(f".*(:?{last_name}|{last_name.upper()}).*") & people_pkw["pkw_name"].str.match(f".*{first_name}.*")]
