# %%
import pandas as pd
import numpy as np
from util.config import versioned
from datetime import datetime, timedelta, date
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from IPython.display import display
from collections import Counter
from analysis.people import find_all_matches, con
import numpy as np

# %%
# people_pkw = pd.DataFrame(versioned.read_jsonl("people_pkw.jsonl"))
# display(people_pkw)

# %%
SCORE_CUTOFF = 10.5
df_all = find_all_matches(con)
df = df_all[df_all["overall_score"] > SCORE_CUTOFF]

# %%
last_name = "Wielichowski"
first_name = ""

# display(people_pkw[people_pkw["pkw_name"].str.match(f".*(:?{last_name}|{last_name.upper()}).*") & people_pkw["pkw_name"].str.match(f".*{first_name}.*")])
display(df[df["pkw_name"].str.match(f".*(:?{last_name}|{last_name.upper()}).*") & df["pkw_name"].str.match(f".*{first_name}.*")])
display(df[df["krs_name"].str.match(f".*(:?{last_name}|{last_name.upper()}).*") & df["krs_name"].str.match(f".*{first_name}.*")])

# %%
def list_values(cols):
    for col in cols:
        for val in df_all[col].unique():
            yield col, val


def test_not_duplicated():
    for column, value in list_values(["krs_name", "pkw_name", "wiki_name"]):
        # Make sure that peeple are not duplicated in the output
        # I.e each value occurs only once in the krs_name, pkw_name or wiki_name in df
        if len(df_all[df_all[column] == value]) > 1:
            print(column, value)

# %%
def find_column_match(column, name):
    name = name.replace(" ", " .*")
    return df[df[column].str.match(name, na=False)]

name = "Adam Borysiewicz"
birth = "1977-12-08"
first_work = "2015-03-04"
rows = find_column_match("krs_name", name)
display(rows)

list(list_values(["krs_name"]))[:5]
