# %%
# In this notebook, we are estimating the total number of companies that we will need to query

# %%
# City x people -> number of companies
# City x people -> number of positions in total (per year)
# SSP  x money  -> number of positions including child companies
